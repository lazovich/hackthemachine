# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
classC_ship1_SSDG = pd.read_csv('/home/ec2-user/hackathon_data/classC_ship1_SSDGV2.csv')

# %%
classC_ship1_MRG = pd.read_csv('/home/ec2-user/hackathon_data/classC_ship1_MRG.csv')

# %%
classC_ship1_MPDE = pd.read_csv('/home/ec2-user/hackathon_data/classC_ship1_MPDE.csv')

# %%
classC_ship2_MPDE = pd.read_csv('/home/ec2-user/hackathon_data/classC_ship2_MPDE.csv')

# %%
classC_ship2_MRG = pd.read_csv('/home/ec2-user/hackathon_data/classC_ship2_MRG.csv')

# %%
classC_ship2_SSDG = pd.read_csv('/home/ec2-user/hackathon_data/classC_ship2_SSDG.csv')

# %%
# Drop the duplicates from all the dataframes
classC_ship1_MRG_noDup = classC_ship1_MRG.drop_duplicates()
classC_ship1_MPDE_noDup = classC_ship1_MPDE.drop_duplicates()
classC_ship1_SSDG_noDup = classC_ship1_SSDG.drop_duplicates()
classC_ship2_MRG_noDup = classC_ship2_MRG.drop_duplicates()
classC_ship2_MPDE_noDup = classC_ship2_MPDE.drop_duplicates()
classC_ship2_SSDG_noDup = classC_ship2_SSDG.drop_duplicates()

# %%
# Make the string time formats into datetime formats
classC_ship1_MRG_times = pd.to_datetime(classC_ship1_MRG_noDup['DateTime'])
classC_ship1_MPDE_times = pd.to_datetime(classC_ship1_MPDE_noDup['DateTime'])
classC_ship1_SSDG_times = pd.to_datetime(classC_ship1_SSDG_noDup['DateTime'])
classC_ship2_MRG_times = pd.to_datetime(classC_ship2_MRG_noDup['DateTime'])
classC_ship2_MPDE_times = pd.to_datetime(classC_ship2_MPDE_noDup['DateTime'])
classC_ship2_SSDG_times = pd.to_datetime(classC_ship2_SSDG_noDup['DateTime'])

classC_ship1_MRG_noDup['timeFormat'] = classC_ship1_MRG_times
classC_ship1_MPDE_noDup['timeFormat'] = classC_ship1_MPDE_times
classC_ship1_SSDG_noDup['timeFormat'] = classC_ship1_SSDG_times
classC_ship2_MRG_noDup['timeFormat'] = classC_ship2_MRG_times
classC_ship2_MPDE_noDup['timeFormat'] = classC_ship2_MPDE_times
classC_ship2_SSDG_noDup['timeFormat'] = classC_ship2_SSDG_times
# Out:
# /home/ec2-user/.local/lib/python2.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /home/ec2-user/.local/lib/python2.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /home/ec2-user/.local/lib/python2.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# Sort the dataframes by time
classC_ship1_MRG_sort = classC_ship1_MRG_noDup.sort_values(['timeFormat'])
classC_ship1_MPDE_sort = classC_ship1_MPDE_noDup.sort_values(['timeFormat'])
classC_ship1_SSDG_sort = classC_ship1_SSDG_noDup.sort_values(['timeFormat'])
classC_ship2_MRG_sort = classC_ship2_MRG_noDup.sort_values(['timeFormat'])
classC_ship2_MPDE_sort = classC_ship2_MPDE_noDup.sort_values(['timeFormat'])
classC_ship2_SSDG_sort = classC_ship2_SSDG_noDup.sort_values(['timeFormat'])

# %%
# Export all of the cleaned dataframes to new folder
classC_ship1_MRG_sort.to_csv('/home/ec2-user/clean_data/classC_ship1_MRG_sort.csv')
classC_ship1_MPDE_sort.to_csv('/home/ec2-user/clean_data/classC_ship1_MPDE_sort.csv')
classC_ship1_SSDG_sort.to_csv('/home/ec2-user/clean_data/classC_ship1_SSDG_sort.csv')
classC_ship2_MRG_sort.to_csv('/home/ec2-user/clean_data/classC_ship2_MRG_sort.csv')
classC_ship2_MPDE_sort.to_csv('/home/ec2-user/clean_data/classC_ship2_MPDE_sort.csv')
classC_ship2_SSDG_sort.to_csv('/home/ec2-user/clean_data/classC_ship2_SSDG_sort.csv')

# %% [markdown]
# # FIRST FOUR FILES CLEANED AND SORTED ->

# %%
# Class A and Class B data files

classA_ship1_allGTG = pd.read_csv('/home/ec2-user/hackathon_data/classA_ship1_allGTG.csv')
classA_ship1_allMRG = pd.read_csv('/home/ec2-user/hackathon_data/classA_ship1_allMRG.csv')
classB_ship2_allGTM = pd.read_csv('/home/ec2-user/hackathon_data/classB_ship2_allGTM.csv')
classB_ship2_allMRG = pd.read_csv('/home/ec2-user/hackathon_data/classB_ship2_allMRG.csv')

# %%
# Drop the duplicates from all the dataframes
classA_ship1_allGTG_noDup = classA_ship1_allGTG.drop_duplicates()
classA_ship1_allMRG_noDup = classA_ship1_allMRG.drop_duplicates()
classB_ship2_allGTM_noDup = classB_ship2_allGTM.drop_duplicates()
classB_ship2_allMRG_noDup = classB_ship2_allMRG.drop_duplicates()

# %%
# Make the string time formats into datetime formats
classA_ship1_GTG_times = pd.to_datetime(classA_ship1_allGTG_noDup['DateTime'])
classA_ship1_MRG_times = pd.to_datetime(classA_ship1_allGTG_noDup['DateTime'])
classB_ship2_GTM_times = pd.to_datetime(classA_ship1_allGTG_noDup['DateTime'])
classB_ship2_MRG_times = pd.to_datetime(classA_ship1_allGTG_noDup['DateTime'])

classA_ship1_allGTG_noDup['timeFormat'] = classA_ship1_GTG_times
classA_ship1_allMRG_noDup['timeFormat'] = classA_ship1_MRG_times
classB_ship2_allGTM_noDup['timeFormat'] = classB_ship2_GTM_times
classB_ship2_allMRG_noDup['timeFormat'] = classB_ship2_MRG_times
# Out:
# /home/ec2-user/.local/lib/python2.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /home/ec2-user/.local/lib/python2.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/ec2-user/.local/lib/python2.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# Sort the dataframes by time
classA_ship1_GTG_sort = classA_ship1_allGTG_noDup.sort_values(['timeFormat'])
classA_ship1_MRG_sort = classA_ship1_allMRG_noDup.sort_values(['timeFormat'])
classB_ship2_GTM_sort = classB_ship2_allGTM_noDup.sort_values(['timeFormat'])
classB_ship2_MRG_sort = classB_ship2_allMRG_noDup.sort_values(['timeFormat'])

# %%
# Export all of the cleaned dataframes to new folder
classA_ship1_GTG_sort.to_csv('/home/ec2-user/clean_data/classA_ship1_GTG_sort.csv')
classA_ship1_MRG_sort.to_csv('/home/ec2-user/clean_data/classA_ship1_MRG_sort.csv')
classB_ship2_GTM_sort.to_csv('/home/ec2-user/clean_data/classB_ship2_GTM_sort.csv')
classB_ship2_MRG_sort.to_csv('/home/ec2-user/clean_data/classB_ship2_MRG_sort.csv')

# %%
classC_ship1_MRG_sort = pd.read_csv('/home/ec2-user/clean_data/classC_ship1_MRG_sort.csv')

# %%
classC_ship1_MRG2_data = classC_ship1_MRG_sort.loc[classC_ship1_MRG_sort['Indicator'] == 'MRG2']

# %%
classC_ship1_MRG_times = pd.to_datetime(classC_ship1_MRG['DateTime'])
classC_ship1_MRG_sort['timeFormat'] = classC_ship1_MRG_times

# %%
plt.figure(figsize=(40, 30))
plt.scatter(classC_ship1_MRG2_data['timeFormat'].astype('int64')/10**9, classC_ship1_MRG2_data['MRG2 LO SUMP LVL'])
plt.show()

# %%
classC_ship1_MRG1_data = classC_ship1_MRG_sort.loc[classC_ship1_MRG_sort['Indicator'] == 'MRG1']

# %%
plt.figure(figsize=(40, 30))
plt.scatter(classC_ship1_MRG1_data['timeFormat'].astype('int64')/10**9, classC_ship1_MRG1_data['MRG1 LO SUMP LVL'])
plt.show()
#classC_ship1_MRG_sort['MRG2 CLUTCH AIR PRES']
#classC_ship1_MRG_sort['MRG2 HMRB PT1 PRES'].plot()
#classC_ship1_MRG_sort['MRG1 LO HDR TEMP'].plot()
#classC_ship1_MRG_sort['MRG2 LO STR DP'].plot()
