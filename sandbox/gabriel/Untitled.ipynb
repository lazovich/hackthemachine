# %%
import pandas as pd
import matplotlib

# %%
classC_ship1_SSDG = pd.read_csv('/home/ec2-user/hackathon_data/classC_ship1_SSDG.csv')

# %%
classC_ship1_SSDG
# Out:
#        Indicator  DG1 FUEL SPLY TEMP  DG4 AFTCLR PMP DISCH P  \
# 0           SSDG          117.000000                     NaN
# 1           SSDG          115.199997                     NaN
# 2           SSDG          113.400002                     NaN
# 3           SSDG          113.400002                     NaN
# 4           SSDG          113.400002                     NaN
# 5           SSDG          106.800003                     NaN
# 6           SSDG           96.400002                     NaN
# 7           SSDG           96.400002                     NaN
# 8           SSDG           96.400002                     NaN
# 9           SSDG           96.400002                     NaN
# 10          SSDG           96.400002                     NaN
# 11          SSDG           96.400002                     NaN
# 12          SSDG           96.400002                     NaN
# 13          SSDG           96.400002                     NaN
# ...
