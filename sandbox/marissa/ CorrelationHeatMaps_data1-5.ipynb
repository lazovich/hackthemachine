# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#**data1 = pd.read_csv('classA_ship1_allGTG.csv')**#
#data2 = pd.read_csv('classA_ship1_allMRG.csv')**#
#data3 = pd.read_csv('classB_ship2_allGTM.csv')**
#data4 = pd.read_csv('classB_ship2_allMRG.csv')**#
#data5 = pd.read_csv('classC_ship1_MPDE.csv')**#

# %%
data = pd.read_csv("/home/ec2-user/hackathon_data/classA_ship1_allGTG.csv", encoding="utf-8")

# %%
plt.figure(figsize=(12, 12))
c = data.corr()
sns.heatmap(c)
# Out:
# /home/ec2-user/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
data = pd.read_csv("/home/ec2-user/hackathon_data/classA_ship1_allMRG.csv", encoding="utf-8")

# %%
plt.figure(figsize=(12, 12))
c = data.corr()
sns.heatmap(c)

# %%
data = pd.read_csv("/home/ec2-user/hackathon_data/classB_ship2_allGTM.csv", encoding="utf-8")

# %%
plt.figure(figsize=(12, 12))
c = data.corr()
sns.heatmap(c)

# %%
data = pd.read_csv("/home/ec2-user/hackathon_data/classB_ship2_allMRG.csv", encoding="utf-8")

# %%
plt.figure(figsize=(12, 12))
c = data.corr()
sns.heatmap(c)

# %%
data = pd.read_csv("/home/ec2-user/hackathon_data/classC_ship1_MPDE.csv", encoding="utf-8")

# %%
plt.figure(figsize=(12, 12))
c = data.corr()
sns.heatmap(c)

# %%
from datetime import datetime
data = pd.read_csv("/home/ec2-user/hackathon_data/classC_ship1_MPDE.csv", encoding="utf-8")

# %%
times = pd.to_datetime(data['DateTime'])
data['timeFormat'] = times

# %%
data
# Out:
#        Indicator  1A RKR LO SPLY PRES  2A CYL 8 EXHAUST TEMP  \
# 0           MPDE            28.299999                    NaN
# 1           MPDE            28.299999                    NaN
# 2           MPDE            28.299999                    NaN
# 3           MPDE            28.299999                    NaN
# 4           MPDE            24.000000                    NaN
# 5           MPDE            34.099998                    NaN
# 6           MPDE            34.200001                    NaN
# 7           MPDE            33.099998                    NaN
# 8           MPDE            33.099998                    NaN
# 9           MPDE            33.099998                    NaN
# 10          MPDE            33.099998                    NaN
# 11          MPDE            33.099998                    NaN
# 12          MPDE            33.099998                    NaN
# 13          MPDE            33.099998                    NaN
# ...

# %%
# find time differences

times = data['timeFormat'].astype('int64')/10**9
time_diffs = times.diff() # number of seconds between rows
time_diffs = time_diffs.drop(0)

#print times[0:20]
print time_diffs[0:20]
print type(time_diffs[0])
print np.sum(time_diffs>0) # number of unique time stamps

print np.sum(np.isnan(time_diffs))

print max(time_diffs), min(time_diffs)
# Out:
# 1       1.0
# 2       6.0
# 3     245.0
# 4     600.0
# 5     384.0
# 6     222.0
# 7     600.0
# 8     600.0
# 9     600.0
# 10    600.0
# 11     86.0
# 12    514.0
# 13    482.0
# 14    118.0
# 15    600.0
# 16     34.0
# 17    566.0
# 18    394.0
# 19    206.0
# 20    218.0
# Name: timeFormat, dtype: float64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-b7b558fd481b> in <module>()
#       7 #print times[0:20]
#       8 print time_diffs[0:20]
# ----> 9 print type(time_diffs[0])
#      10 print np.sum(time_diffs>0) # number of unique time stamps
#      11
#
# /home/ec2-user/anaconda2/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     599         key = com._apply_if_callable(key, self)
#     600         try:
# --> 601             result = self.index.get_value(self, key)
#     602
# ...

# %%
time_bool = np.logical_and( time_diffs != 0, time_diffs < 1000)
time_diff_subset = time_diffs[time_bool]
plt.figure(1)
plt.hist(time_diff_subset)

plt.show()

# %%
data = pd.read_csv("/home/ec2-user/hackathon_data/classC_ship1_MRG.csv")

# %%
plt.figure(figsize=(12, 12))
c = data.corr()
sns.heatmap(c)
