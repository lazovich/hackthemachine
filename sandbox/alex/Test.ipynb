# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as pp
import pandas as pd

# %%
pp.plot(np.random.random(100))

# %%
pd.read_csv("../../../hackathon_data/classA_ship1_allGTG.csv")
# Out:
#                   DateTime    VOLTAGE  TURBINE INLET TEMP  TURB OVER TEMP  \
# 0           7/22/2016 1:44   5.300000           84.000000               0
# 1           7/22/2016 1:44   7.000000           84.000000               0
# 2           7/22/2016 1:44  11.700000           85.000000               0
# 3           7/22/2016 1:44  20.500000           85.900002               0
# 4           7/22/2016 1:45  33.700001          102.500000               0
# 5           7/22/2016 2:12  49.500000          351.600006               0
# 6           7/22/2016 2:12  36.000000          343.799988               0
# 7           7/22/2016 2:12  26.700001          336.899994               0
# 8           7/22/2016 2:12  21.700001          334.000000               0
# 9           7/22/2016 2:12  16.100000          329.100006               0
# 10          7/23/2016 4:47  47.200001          346.700012               0
# 11          7/23/2016 4:47  34.000000          339.799988               0
# ...

# %%
import os
for file in os.listdir("../../../hackathon_data/"):
    print(file)
# Out:
# classC_ship1_SSDG.csv
# classC_ship2_MPDE.csv
# Collection_Sheet_HACKtheMACHINE.docx
# classC_ship2_MPDE.csv.c61BDfBA
# classA_ship1_allGTG.csv
# classB_ship2_allGTM.csv
# classC_ship2_SSDG.csv.5f6d96b5
# classC_ship2_MRG.csv
# classB_ship2_allMRG.csv
# classC_ship2_SSDG.csv
# Data_Dictionary.xlsx
# classC_ship1_MPDE.csv
# classA_ship1_allMRG.csv
# classC_ship1_MRG.csv

# %%
data = {}
path = "/hackathon_data/"
for file in os.listdir(p):
    data[file] = pd.read_csv(file)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-10-d31a00ab936d> in <module>()
#       1 data = {}
#       2 for file in os.listdir("../../../hackathon_data/"):
# ----> 3     data[file] = pd.read_csv(file)
#
# ...
